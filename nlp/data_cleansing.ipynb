# %%
from albumentations import Compose, HorizontalFlip, VerticalFlip, RandomBrightnessContrast, Resize
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from albumentations import Compose, HorizontalFlip, VerticalFlip, RandomBrightnessContrast, Resize
#
# File /opt/conda/lib/python3.10/site-packages/albumentations/__init__.py:5
#       1 __version__ = "1.4.7"
#       3 from albumentations.check_version import check_for_updates
# ----> 5 from .augmentations import *
#       6 from .core.composition import *
#       7 from .core.serialization import *
#
# File /opt/conda/lib/python3.10/site-packages/albumentations/augmentations/__init__.py:5
#       3 from .crops.functional import *
#       4 from .crops.transforms import *
# ----> 5 from .domain_adaptation import *
#       6 from .domain_adaptation_functional import *
#       7 from .dropout.channel_dropout import *
#
# ...
